# %% [markdown]
# # Type of functions:
# - Pure functions
# - Impure functions
# - Recursive functions
# - Anonymous functions (Lambda functions)

# %% [markdown]
# ## Pure functions:
# A function that, given the same input, will always return the same output and does not have any side effects (i.e., it does not modify any external state or variables).

# %%
# Pure functions
def pure_chai(cups):
    return cups * 10


total_chai = 0

# %% [markdown]
# ## Impure functions:
# A function that may produce different outputs for the same input or has side effects, such as modifying external variables or states.
# - For example, a function that modifies a global variable or prints to the console is considered impure.

# %%
# Impure Function - not recommended

total_chai = 0
def impure_chai(cups):
    global total_chai
    total_chai += cups

# %% [markdown]
# ## Recursive functions:
# A function that calls itself in order to solve a problem. Recursive functions typically have a base case to terminate the recursion and a recursive case that breaks the problem down into smaller subproblems.

# %%
# Recursive functions

def pour_chai(n):
    print(n)
    if n == 0:
        return "All cups poured"
    return pour_chai(n-1)


print(pour_chai(3))

chai_types = ["light", "kadak", "ginger", "kadak"]
# Out:
# 3
# 2
# 1
# 0
# All cups poured

# %% [markdown]
# ## Lambda Functions in Python
# Lambda functions are small anonymous functions defined using the **lambda** keyword. They can have any number of arguments but only one expression. They are commonly used for short operations or as arguments to higher-order functions.
# - **Syntax**:
#   ```python
#   lambda arguments: expression
#   ```
# - **Example**:
#   ```python
#     # same as:
#     # def add(x, y):
#     #     return x + y
#     add = lambda x, y: x + y
#
#     print(add(2, 3))  # Output: 5
# ```

# %%
# anonymous functions (lambda)
# filter (function, iterable) so here function is lambda chai: chai!="kadak" which fill return True or False for each chai in chai_types list and if the result is True then that chai will be added to the new list strong_chai
strong_chai = list(filter(lambda chai: chai != "kadak", chai_types))
# without lambda

def is_strong(chai):
    return chai != "kadak"


a_chai = list(filter(is_strong, chai_types))

print(a_chai)
print(strong_chai)

# %%
def even(num):
    if num%2==0:
        return True
    
even(24)

even_lambda = lambda num: num%2==0
even_lambda(24)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z

addition(12,13,14)


def addition1(x, y, z): return x+y+z
addition1(12, 13,14)
# Out:
# 39

# %%
## map()- applies a function to all items in a list
numbers=[1,2,3,4,5,6]
def square(number):
    return number**2

square(2)


list(map(lambda x: x**2,numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
#  Immediately Invoked Lambda Expression (IIFE)
words = ['apple', 'banana', 'cherry', 'date']
(lambda ws: max(map(len, ws), default=0))(words)
